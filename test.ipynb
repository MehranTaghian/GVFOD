# %%
path = 'exp/exp_gvfod/results/train_size_delay_0_default_False_trainloss_False.json'

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
# Out:
# /home/taghianj/Documents/env/lib/python3.8/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
data = pd.read_json(path)

# %% [markdown]
# Those start with c_ means that they classified "Correctly" and those with ic_ means that classified "incorrectly"

# %%
data
# Out:
#         Algorithm  Time of Start  Training Size  Testing Size  Delay  \
# 0         IForest           1140             50           600      0
# 1           OCSVM           1140             50           600      0
# 2             LOF           1140             50           600      0
# 3            ABOD           1140             50           600      0
# 4             KNN           1140             50           600      0
# ...           ...            ...            ...           ...    ...
# 4395          MCD              0           2000           600      0
# 4396          PCA              0           2000           600      0
# 4397  MarkovChain              0           2000           600      0
# 4398          HMM              0           2000           600      0
# 4399        GVFOD              0           2000           600      0
#
#        Train Time  Test Time  c_Normal  ic_Normal  c_loose_l1  ic_loose_l1  \
# ...

# %%
path = 'exp/exp_gvfod/figures/res.csv'

# %%
res = pd.read_csv(path)
res
# Out:
#       Unnamed: 0    Algorithm  Time of Start  Training Size  Testing Size  \
# 0              0      IForest           1140             50           600
# 1              1        OCSVM           1140             50           600
# 2              2          LOF           1140             50           600
# 3              3         ABOD           1140             50           600
# 4              4          KNN           1140             50           600
# ...          ...          ...            ...            ...           ...
# 4395        4395          MCD              0           2000           600
# 4396        4396          PCA              0           2000           600
# 4397        4397  MarkovChain              0           2000           600
# 4398        4398          HMM              0           2000           600
# 4399        4399        GVFOD              0           2000           600
#
#       Delay   Train Time  Test Time  c_Normal  ic_Normal  ...  c_tight  \
# ...

# %%
x

# %%
gvfod = res[res['Algorithm'] == 'GVFOD']
a = sns.lineplot(np.array(gvfod['Training Size']), np.array(gvfod['f1_score_loose_l1']), )
# Out:
# /home/taghianj/Documents/env/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
